# %%
# SQL Analysis – Sales Project

# %%
## Query 1: Total Revenue

# %%
pip install ipython-sql mysql-connector-python
# Out:
# ...
#   Using cached ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached mysql_connector_python-9.5.0-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# ...
#   Using cached prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# ...
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# ...
# Using cached ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Using cached mysql_connector_python-9.5.0-cp313-cp313-win_amd64.whl (16.5 MB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------ --------------- 1.3/2.1 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.6 MB/s  0:00:00
# ...
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached prettytable-3.17.0-py3-none-any.whl (34 kB)
# ...
#
#    ---------------------------------------- 0/7 [ipython-genutils]
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+mysqlconnector://root:7878@localhost/sales_project

# %%
# %sql mysql+mysqlconnector://7878@localhost/sales_project
# Out:
# Traceback (most recent call last):
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py", line 354, in _open_connection
#     self._cmysql.connect(**cnx_kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
# _mysql_connector.MySQLInterfaceError: Access denied for user '7878'@'localhost' (using password: NO)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 3309, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
# ...

# %%
# %sql mysql+mysqlconnector://root@localhost/sales_project

# %%
# %%sql
# SELECT DATABASE();
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sales_project
# 1 rows affected.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT DATABASE();\n')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %load_ext sql

# %%
# %sql mysql+mysqlconnector://7878@localhost/sales_project
# Out:
# Traceback (most recent call last):
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py", line 354, in _open_connection
#     self._cmysql.connect(**cnx_kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
# _mysql_connector.MySQLInterfaceError: Access denied for user '7878'@'localhost' (using password: NO)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 3309, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
# ...

# %%
# %sql mysql+mysqlconnector://root@localhost/sales_project
# Out:
# Traceback (most recent call last):
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py", line 354, in _open_connection
#     self._cmysql.connect(**cnx_kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
# _mysql_connector.MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: NO)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\GiGaNiGGa\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py", line 3309, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
# ...

# %%
# %sql mysql+mysqlconnector://root:7878@localhost/sales_project

# %%
# %sql SELECT DATABASE();
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sales_project
# 1 rows affected.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_line_magic('sql', 'SELECT DATABASE();')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
